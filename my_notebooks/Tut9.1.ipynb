# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import os;
import tensorflow as tf;
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
sns.set_style('whitegrid')
# Out:
# 2025-03-31 11:02:53.945787: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-31 11:02:53.947747: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-31 11:02:53.951692: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-31 11:02:53.960995: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743418973.976337   29331 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743418973.980801   29331 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743418973.992933   29331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743418973.992957   29331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743418973.992959   29331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743418973.992960   29331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-31 11:02:53.997407: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# workflow

# %%
data = fetch_california_housing()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['price'] = pd.Series(data.target)
print(df.shape)
df.head()
# Out:
# (20640, 9)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# split dataset

# %% [markdown]
# train snd test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['price'], axis=1),
    df['price'],
    test_size=0.2,
    random_state=0
)
print("* Train set:", X_train.shape, y_train.shape, "\n* Test set:", X_test.shape, y_test.shape)
# Out:
# * Train set: (16512, 8) (16512,)
# * Test set: (4128, 8) (4128,)

# %% [markdown]
# split validation set

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=0
)
print("* Train set:", X_train.shape, y_train.shape)
print("* Validation set:", X_val.shape, y_val.shape)
print("* Test set:", X_test.shape, y_test.shape)
# Out:
# * Train set: (13209, 8) (13209,)
# * Validation set: (3303, 8) (3303,)
# * Test set: (4128, 8) (4128,)

# %% [markdown]
# create pipeline for processing

# %%
def pipeline_pre_processing():
    """
    Define data preparation pipeline
    """
    pipeline_base = Pipeline([

      ( "feat_scaling", StandardScaler() )

    ])
    return pipeline_base

# %%
pipeline = pipeline_pre_processing()
X_train = pipeline.fit_transform(X_train)
X_val= pipeline.transform(X_val)
X_test = pipeline.transform(X_test)

# %% [markdown]
# create deep learning network

# %%
def create_tf_model(n_features):

  model = Sequential()
  model.add(Dense(units=n_features, activation='relu', input_shape=(n_features,)))

  model.add(Dense(units=8,activation='relu'))
  model.add(Dropout(0.25))

  model.add(Dense(units=4,activation='relu'))
  model.add(Dropout(0.25))

  model.add(Dense(units=1))
  model.compile(loss='mse', optimizer='adam')

  return model

# %%
model = create_tf_model(n_features=X_train.shape[1])
model.summary()
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-31 11:02:55.702426: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185 (740.00 B)
#  Trainable params: 185 (740.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# visualize network structure

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='../outputs/models/nn_regression.png')
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %% [markdown]
# fit the model

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

# %%
model.fit(x=X_train,
          y=y_train,
          epochs=100,
          validation_data=(X_val, y_val),
          verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.3226 - val_loss: 1.1238
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5387 - val_loss: 0.7273
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1952 - val_loss: 0.5731
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0426 - val_loss: 0.5523
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9113 - val_loss: 0.4725
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8720 - val_loss: 0.4707
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7584 - val_loss: 0.4643
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7211 - val_loss: 0.4735
# Epoch 9/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7034 - val_loss: 0.4734
# Epoch 10/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6278 - val_loss: 0.4291
# Epoch 11/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6636 - val_loss: 0.4633
# Epoch 12/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6064 - val_loss: 0.4634
# Epoch 13/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6263 - val_loss: 0.4431
# Epoch 14/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6251 - val_loss: 0.4230
# Epoch 15/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6005 - val_loss: 0.4214
# Epoch 16/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5970 - val_loss: 0.4426
# Epoch 17/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6055 - val_loss: 0.4310
# Epoch 18/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5972 - val_loss: 0.4166
# Epoch 19/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5668 - val_loss: 0.4066
# Epoch 20/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6084 - val_loss: 0.4187
# Epoch 21/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5779 - val_loss: 0.4161
# Epoch 22/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5839 - val_loss: 0.4174
# Epoch 23/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5768 - val_loss: 0.4042
# Epoch 24/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5663 - val_loss: 0.4224
# Epoch 25/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5505 - val_loss: 0.3935
# Epoch 26/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5778 - val_loss: 0.3920
# Epoch 27/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5504 - val_loss: 0.4094
# Epoch 28/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5713 - val_loss: 0.4123
# Epoch 29/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5596 - val_loss: 0.3953
# Epoch 30/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5536 - val_loss: 0.3839
# Epoch 31/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5429 - val_loss: 0.3930
# Epoch 32/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5411 - val_loss: 0.3923
# Epoch 33/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5484 - val_loss: 0.3757
# Epoch 34/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5192 - val_loss: 0.3726
# Epoch 35/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5141 - val_loss: 0.3869
# Epoch 36/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5321 - val_loss: 0.3795
# Epoch 37/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5303 - val_loss: 0.3872
# Epoch 38/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5139 - val_loss: 0.3731
# Epoch 39/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5209 - val_loss: 0.3704
# Epoch 40/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5005 - val_loss: 0.3699
# Epoch 41/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5216 - val_loss: 0.3776
# Epoch 42/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5319 - val_loss: 0.3830
# Epoch 43/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5073 - val_loss: 0.3748
# Epoch 44/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5065 - val_loss: 0.3688
# Epoch 45/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5136 - val_loss: 0.3853
# Epoch 46/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5226 - val_loss: 0.3953
# Epoch 47/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5194 - val_loss: 0.3775
# Epoch 48/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5277 - val_loss: 0.3830
# Epoch 49/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5130 - val_loss: 0.3923
# Epoch 50/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5171 - val_loss: 0.3829
# Epoch 51/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5192 - val_loss: 0.3757
# Epoch 52/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5287 - val_loss: 0.3761
# Epoch 53/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5079 - val_loss: 0.3859
# Epoch 54/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5045 - val_loss: 0.3828
# Epoch 55/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5189 - val_loss: 0.3773
# Epoch 56/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5081 - val_loss: 0.3785
# Epoch 57/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5139 - val_loss: 0.3737
# Epoch 58/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5176 - val_loss: 0.3987
# Epoch 59/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5239 - val_loss: 0.3768
# Epoch 59: early stopping

# %% [markdown]
# model evaluation

# %%
losses = pd.DataFrame(model.history.history)
losses
# Out:
#         loss  val_loss
# 0   3.171718  1.123757
# 1   1.429778  0.727337
# 2   1.135662  0.573138
# 3   0.999485  0.552326
# 4   0.893392  0.472514
# 5   0.818369  0.470656
# 6   0.746320  0.464266
# 7   0.697417  0.473520
# 8   0.695103  0.473404
# 9   0.642392  0.429058
# 10  0.644613  0.463318
# 11  0.619413  0.463415
# 12  0.609760  0.443138
# 13  0.611527  0.422983
# 14  0.602454  0.421402
# 15  0.605077  0.442646
# 16  0.606621  0.431041
# 17  0.593635  0.416623
# 18  0.580152  0.406576
# 19  0.597314  0.418686
# 20  0.580434  0.416144
# 21  0.578016  0.417419
# 22  0.574873  0.404170
# 23  0.573277  0.422389
# 24  0.559486  0.393495
# 25  0.579712  0.391962
# 26  0.568600  0.409426
# 27  0.572199  0.412251
# 28  0.546320  0.395305
# 29  0.538186  0.383883
# 30  0.540989  0.393032
# 31  0.529013  0.392299
# 32  0.536045  0.375674
# 33  0.532032  0.372576
# 34  0.531305  0.386856
# 35  0.523158  0.379515
# 36  0.530693  0.387223
# 37  0.527373  0.373094
# 38  0.524401  0.370448
# 39  0.514707  0.369937
# 40  0.528425  0.377625
# 41  0.532121  0.382961
# 42  0.517439  0.374842
# 43  0.514936  0.368754
# 44  0.515824  0.385310
# 45  0.519082  0.395315
# 46  0.510681  0.377467
# 47  0.512427  0.382992
# 48  0.525804  0.392254
# 49  0.533579  0.382864
# 50  0.518127  0.375661
# 51  0.523393  0.376057
# 52  0.512528  0.385884
# 53  0.513622  0.382830
# 54  0.521916  0.377276
# 55  0.520139  0.378524
# 56  0.526101  0.373726
# 57  0.519819  0.398659
# 58  0.520200  0.376797

# %%
sns.set_style("whitegrid")
losses[['loss','val_loss']].plot(style='.-')
plt.title("Loss")
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3790
# 0.36253178119659424

# %%
def regression_performance(X_train, y_train,
                           X_val, y_val,
                           X_test, y_test,pipeline):
    """
    Assessment of performance of CNN regression model
    """
    print("Model Evaluation \n")
    print("* Train Set")
    regression_evaluation(X_train,y_train,pipeline)
    print("* Validation Set")
    regression_evaluation(X_val, y_val,pipeline)
    print("* Test Set")
    regression_evaluation(X_test,y_test,pipeline)

def regression_evaluation(X, y, pipeline):
    """
    Gets features and target (either from train or test set) and pipeline.
    - Predicts using the pipeline and the features
    - Calculates performance metrics comparing the prediction to the target
    """
    prediction = pipeline.predict(X)
    print('R2 Score:', round(r2_score(y, prediction), 3))
    print('Mean Absolute Error:', round(mean_absolute_error(y, prediction), 3))
    print('Mean Squared Error:', round(mean_squared_error(y, prediction), 3))
    print('Root Mean Squared Error:', round(np.sqrt(mean_squared_error(y, prediction)), 3))
    print("\n")
    

def regression_evaluation_plots(X_train, y_train,
                                X_val, y_val,
                                X_test, y_test,
                                pipeline, alpha_scatter=0.5):
    """
    Plot regression evaluation
    """
    pred_train = pipeline.predict(X_train).reshape(-1)
    # we reshape the prediction arrays to be in the format (n_rows,), so we can plot it after
    pred_val = pipeline.predict(X_val).reshape(-1)
    pred_test = pipeline.predict(X_test).reshape(-1)
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,6))
    
    sns.scatterplot(x=y_train , y=pred_train, alpha=alpha_scatter, ax=axes[0])
    
    sns.lineplot(x=y_train , y=y_train, color='red', ax=axes[0])
    axes[0].set_xlabel("Actual")
    axes[0].set_ylabel("Predictions")
    axes[0].set_title("Train Set")
    
    sns.scatterplot(x=y_val , y=pred_val, alpha=alpha_scatter, ax=axes[1])
    
    sns.lineplot(x=y_val , y=y_val, color='red', ax=axes[1])
    axes[1].set_xlabel("Actual")
    axes[1].set_ylabel("Predictions")
    axes[1].set_title("Validation Set")
    
    sns.scatterplot(x=y_test , y=pred_test, alpha=alpha_scatter, ax=axes[2])
    sns.lineplot(x=y_test , y=y_test, color='red', ax=axes[2])
    axes[2].set_xlabel("Actual")
    axes[2].set_ylabel("Predictions")
    axes[2].set_title("Test Set")
    
    plt.show()

# %%
regression_performance(X_train, y_train,X_val, y_val, X_test, y_test,model)
regression_evaluation_plots(X_train, y_train, X_val, y_val,X_test, y_test,
                            model, alpha_scatter=0.5)
# Out:
# Model Evaluation
#
# * Train Set
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# R2 Score: 0.732
# Mean Absolute Error: 0.439
# Mean Squared Error: 0.359
# Root Mean Squared Error: 0.599
#
#
# * Validation Set
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# R2 Score: 0.718
# Mean Absolute Error: 0.444
# Mean Squared Error: 0.377
# Root Mean Squared Error: 0.614
#
#
# * Test Set
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# R2 Score: 0.722
# Mean Absolute Error: 0.445
# Mean Squared Error: 0.363
# Root Mean Squared Error: 0.602
#
#
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step

# %% [markdown]
# prediction

# %%
X_test.shape
# Out:
# (4128, 8)

# %%
live_data = X_test[54:55,:]
live_data
# Out:
# array([[-1.2449854 , -0.20116759, -1.69946574, -0.09213495, -0.2003886 ,
#          0.14367436, -0.73320429,  0.64473104]])

# %%
model.predict(live_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# array([[1.6712545]], dtype=float32)

# %%
sample = pd.DataFrame({
    'MedInc': [8.325200],
    'HouseAge': [41.000000],
    'AveRooms': [6.984127],
    'AveBedrms': [1.023810],
    'Population': [322.000000],
    'AveOccup': [2.555556],
    'Latitude': [37.880000],
    'Longitude': [-122.230000] 
})

sample
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#
#    Longitude
# 0    -122.23

# %%
sample_cnn = pipeline.transform(sample.values)
sample_cnn
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.33427752,  0.99158883,  0.69465782, -0.1578881 , -0.98629534,
#         -0.08184656,  1.04783331, -1.3256435 ]])

# %%
predicted_price = model.predict(sample_cnn)[0][0]
print('---------------')
print(f"Predicted house price based on the information provided is: {predicted_price:.2f} arb. units.")
print('---------------')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ---------------
# Predicted house price based on the information provided is: 3.88 arb. units.
# ---------------

# %% [markdown]
# save and load model

# %%
model.save('../outputs/models/nn_regression.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
